# %%
sorted(list(chart_listener_matches))[:30]
# Out:
# ['aj tracey',
#  'amaarae',
#  'anuel aa',
#  'avicii',
#  'bad bunny',
#  'christian nodal',
#  'city girls',
#  'dua lipa',
#  'greeicy',
#  'gusttavo lima',
#  'henrique & juliano',
#  'iann dior',
#  'iron maiden',
#  'j balvin',
#  'john newman',
#  'jorge & mateus',
#  'jt',
#  'jul',
#  'kali uchis',
#  'lil durk',
#  'lunay',
#  'machine gun kelly',
#  'maiara & maraisa',
#  'maroon 5',
#  'matisse',
#  'meek mill',
#  'mustard',
#  'nav',
#  'nick jonas',
#  'omar montes']

# %%
chart_artist_names = set(
    charts_artists_exploded["artist_clean"].dropna()
)

chart_listener_matches = chart_artist_names.intersection(listener_artists)

len(chart_listener_matches)
# Out:
# 42

# %%
charts_artists_exploded["artist_clean"] = (
    charts_artists_exploded["artist_list"]
    .str.lower()
    .str.strip()
)

charts_artists_exploded[
    ["artist_list", "artist_clean"]
].head(15)
# Out:
#                 artist_list             artist_clean
# 0                Haftbefehl               haftbefehl
# 1                   Suchmos                  suchmos
# 2                  Nilipek.                 nilipek.
# 3                  Nilipek.                 nilipek.
# 4                  Nilipek.                 nilipek.
# 5                  Nilipek.                 nilipek.
# 6                    Kalido                   kalido
# 6             Totoy El Frio            totoy el frio
# 6                HIT$ MUSIC               hit$ music
# 7   Totova & Freddie Shuman  totova & freddie shuman
# 7                Begi Lotfi               begi lotfi
# 8                  Jay Chou                 jay chou
# 9                  Jay Chou                 jay chou
# 10                 Jay Chou                 jay chou
# 11                 Jay Chou                 jay chou

# %%
charts_artists_exploded = charts_artist_sample.explode("artist_list")

charts_artists_exploded[
    ["name", "artist_list"]
].head(15)
# Out:
#                   name              artist_list
# 0           Crackküche               Haftbefehl
# 1                WATER                  Suchmos
# 2   Gözleri Aşka Gülen                 Nilipek.
# 3   Gözleri Aşka Gülen                 Nilipek.
# 4   Gözleri Aşka Gülen                 Nilipek.
# 5   Gözleri Aşka Gülen                 Nilipek.
# 6             Opciones                   Kalido
# 6             Opciones            Totoy El Frio
# 6             Opciones               HIT$ MUSIC
# 7          Hosszú Idők  Totova & Freddie Shuman
# 7          Hosszú Idők               Begi Lotfi
# 8                 愛你沒差                 Jay Chou
# 9                 愛你沒差                 Jay Chou
# 10                愛你沒差                 Jay Chou
# 11                愛你沒差                 Jay Chou

# %%
import ast

charts_artist_sample["artist_list"] = charts_artist_sample["artists"].apply(
    ast.literal_eval
)

charts_artist_sample[
    ["name", "artists", "artist_list"]
].head(10)
# Out:
#                  name                                    artists  \
# 0          Crackküche                             ['Haftbefehl']
# 1               WATER                                ['Suchmos']
# 2  Gözleri Aşka Gülen                               ['Nilipek.']
# 3  Gözleri Aşka Gülen                               ['Nilipek.']
# 4  Gözleri Aşka Gülen                               ['Nilipek.']
# 5  Gözleri Aşka Gülen                               ['Nilipek.']
# 6            Opciones  ['Kalido', 'Totoy El Frio', 'HIT$ MUSIC']
# 7         Hosszú Idők  ['Totova & Freddie Shuman', 'Begi Lotfi']
# 8                愛你沒差                               ['Jay Chou']
# 9                愛你沒差                               ['Jay Chou']
#
#                              artist_list
# 0                           [Haftbefehl]
# 1                              [Suchmos]
# 2                             [Nilipek.]
# 3                             [Nilipek.]
# 4                             [Nilipek.]
# ...

# %%
charts_artist_sample[
    charts_artist_sample["artists"].str.contains(",", na=False)
][["name", "artists"]].head(10)
# Out:
#                              name                                    artists
# 6                        Opciones  ['Kalido', 'Totoy El Frio', 'HIT$ MUSIC']
# 7                     Hosszú Idők  ['Totova & Freddie Shuman', 'Begi Lotfi']
# 424  Algo Mais (Amante) - Ao Vivo            ['Xand Avião', 'Gusttavo Lima']
# 425  Algo Mais (Amante) - Ao Vivo            ['Xand Avião', 'Gusttavo Lima']
# 426  Algo Mais (Amante) - Ao Vivo            ['Xand Avião', 'Gusttavo Lima']
# 427  Algo Mais (Amante) - Ao Vivo            ['Xand Avião', 'Gusttavo Lima']
# 428  Algo Mais (Amante) - Ao Vivo            ['Xand Avião', 'Gusttavo Lima']
# 429  Algo Mais (Amante) - Ao Vivo            ['Xand Avião', 'Gusttavo Lima']
# 430  Algo Mais (Amante) - Ao Vivo            ['Xand Avião', 'Gusttavo Lima']
# 431  Algo Mais (Amante) - Ao Vivo            ['Xand Avião', 'Gusttavo Lima']

# %%
charts_artist_sample = pd.read_csv(
    "../data/raw/charts.csv.zip",
    compression="zip",
    usecols=["name", "artists"],
    nrows=10000
)

charts_artist_sample.shape
# Out:
# (10000, 2)

# %%
charts_sample_df[
    charts_sample_df["artists"].str.contains(",", na=False)
][["name", "artists"]].head(10)
# Out:
# Empty DataFrame
# Columns: [name, artists]
# Index: []

# %%
sorted(list(common_artists))[:30]
# Out:
# ['$uicideboy$',
#  '(g)i-dle',
#  '*nsync',
#  '1nonly',
#  '21 savage',
#  '24kgoldn',
#  '347aidan',
#  '42 dugg',
#  '5 seconds of summer',
#  '50 cent',
#  '6arelyhuman',
#  '6ix9ine',
#  '6ynthmane',
#  'a boogie wit da hoodie',
#  'a great big world',
#  'a$ap ferg',
#  'a$ap rocky',
#  'aaron smith',
#  'aastha gill',
#  'acraze',
#  'adele',
#  'ado',
#  'aerosmith',
#  'aespa',
#  'agroplay',
#  'agust d',
#  'aitch',
#  'ajr',
#  'akon',
#  'alan walker']

# %%
listener_artists = set(listeners_df["Artist"].str.lower().str.strip())
spotify_artists = set(
    spotify_df["Artist"]
    .dropna()
    .str.lower()
    .str.strip()
)

common_artists = listener_artists.intersection(spotify_artists)

len(common_artists)
# Out:
# 1003

# %%
spotify_df["Artist"].nunique()
# Out:
# 1999

# %%
spotify_df.duplicated().sum()
# Out:
# np.int64(2)

# %%
spotify_df.isnull().sum()
# Out:
# Track                            0
# Album Name                       0
# Artist                           5
# Release Date                     0
# ISRC                             0
# All Time Rank                    0
# Track Score                      0
# Spotify Streams                113
# Spotify Playlist Count          70
# Spotify Playlist Reach          72
# Spotify Popularity             804
# YouTube Views                  308
# YouTube Likes                  315
# TikTok Posts                  1173
# TikTok Likes                   980
# TikTok Views                   981
# YouTube Playlist Reach        1009
# Apple Music Playlist Count     561
# AirPlay Spins                  498
# SiriusXM Spins                2123
# Deezer Playlist Count          921
# Deezer Playlist Reach          928
# Amazon Playlist Count         1055
# Pandora Streams               1106
# Pandora Track Stations        1268
# Soundcloud Streams            3333
# Shazam Counts                  577
# ...

# %%
spotify_df = pd.read_csv(
    "../data/raw/Most Streamed Spotify Songs 2024.csv.zip",
    compression="zip",
    encoding="latin-1"
)

spotify_df.shape
# Out:
# (4600, 29)

# %%
spotify_sample_df.dtypes
# Out:
# Track                             str
# Album Name                        str
# Artist                            str
# Release Date                      str
# ISRC                              str
# All Time Rank                   int64
# Track Score                   float64
# Spotify Streams                   str
# Spotify Playlist Count            str
# Spotify Playlist Reach            str
# Spotify Popularity              int64
# YouTube Views                     str
# YouTube Likes                     str
# TikTok Posts                      str
# TikTok Likes                      str
# TikTok Views                      str
# YouTube Playlist Reach            str
# Apple Music Playlist Count      int64
# AirPlay Spins                     str
# SiriusXM Spins                    str
# Deezer Playlist Count           int64
# Deezer Playlist Reach             str
# Amazon Playlist Count           int64
# Pandora Streams                   str
# Pandora Track Stations            str
# ...

# %%
spotify_sample_df.columns.tolist()
# Out:
# ['Track',
#  'Album Name',
#  'Artist',
#  'Release Date',
#  'ISRC',
#  'All Time Rank',
#  'Track Score',
#  'Spotify Streams',
#  'Spotify Playlist Count',
#  'Spotify Playlist Reach',
#  'Spotify Popularity',
#  'YouTube Views',
#  'YouTube Likes',
#  'TikTok Posts',
#  'TikTok Likes',
#  'TikTok Views',
#  'YouTube Playlist Reach',
#  'Apple Music Playlist Count',
#  'AirPlay Spins',
#  'SiriusXM Spins',
#  'Deezer Playlist Count',
#  'Deezer Playlist Reach',
#  'Amazon Playlist Count',
#  'Pandora Streams',
#  'Pandora Track Stations',
#  'Soundcloud Streams',
#  'Shazam Counts',
#  'TIDAL Popularity',
#  'Explicit Track']

# %%
spotify_sample_df = pd.read_csv(
    "../data/raw/Most Streamed Spotify Songs 2024.csv.zip",
    compression="zip",
    encoding="latin-1",
    nrows=5
)

spotify_sample_df
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC  All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528              1        725.4     390,470,936
# 1     5/4/2024  USUG12400910              2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387              3        538.4     601,309,283
# 3    1/12/2023  USSM12209777              4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398              5        423.3     107,034,922
#
# ...

# %%
import zipfile

with zipfile.ZipFile(
    "../data/raw/Most Streamed Spotify Songs 2024.csv.zip",
    "r"
) as zip_file:

    with zip_file.open("Most Streamed Spotify Songs 2024.csv") as csv_file:
        raw_sample = csv_file.read(5000)

raw_sample[:200]
# Out:
# b'Track,Album Name,Artist,Release Date,ISRC,All Time Rank,Track Score,Spotify Streams,Spotify Playlist Count,Spotify Playlist Reach,Spotify Popularity,YouTube Views,YouTube Likes,TikTok Posts,TikTok Lik'

# %%
spotify_sample_df = pd.read_csv(
    "../data/raw/Most Streamed Spotify Songs 2024.csv.zip",
    compression="zip",
    nrows=5
)

spotify_sample_df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 spotify_sample_df = pd.read_csv(
#       2     "../data/raw/Most Streamed Spotify Songs 2024.csv.zip",
#       3     compression="zip",
#       4     nrows=5
#
# File ~/Documents/Final-year-projects/PMIP/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
with zipfile.ZipFile(
    "../data/raw/Most Streamed Spotify Songs 2024.csv.zip",
    "r"
) as zip_file:
    print(zip_file.namelist())
# Out:
# ['Most Streamed Spotify Songs 2024.csv']

# %%
row_count = 0

for chunk in pd.read_csv(
    "../data/raw/charts.csv.zip",
    compression="zip",
    chunksize=100000
):
    row_count += len(chunk)

row_count
# Out:
# 5428021

# %%
charts_sample_df.dtypes
# Out:
# date               str
# country            str
# position         int64
# streams          int64
# track_id           str
# artists            str
# artist_genres      str
# duration         int64
# explicit          bool
# name               str
# dtype: object

# %%
charts_sample_df.columns.tolist()
# Out:
# ['date',
#  'country',
#  'position',
#  'streams',
#  'track_id',
#  'artists',
#  'artist_genres',
#  'duration',
#  'explicit',
#  'name']

# %%
charts_sample_df = pd.read_csv(
    "../data/raw/charts.csv.zip",
    compression="zip",
    nrows=5
)

charts_sample_df
# Out:
#          date country  position  streams                track_id  \
# 0  2021/04/15      de        82   625718  20IvMlpi4U5RuDnAlXSRiV
# 1  2019/01/31      jp       171    50896  0V1K6MU0utODk4yNqZKsFv
# 2  2018/11/15      tr        59   185439  4qzZm5EIdFurBpDieEmVc9
# 3  2018/11/22      tr       133   111159  4qzZm5EIdFurBpDieEmVc9
# 4  2018/11/29      tr       166    96204  4qzZm5EIdFurBpDieEmVc9
#
#           artists                                      artist_genres  \
# 0  ['Haftbefehl']                                 ['german hip hop']
# 1     ['Suchmos']  ['japanese r&b', 'j-rock', 'japanese soul', 'j...
# 2    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 3    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 4    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
#
#    duration  explicit                name
# 0    198746     False          Crackküche
# 1    408320     False               WATER
# ...

# %%
import zipfile

with zipfile.ZipFile("../data/raw/charts.csv.zip", "r") as zip_file:
    print(zip_file.namelist())
# Out:
# ['charts.csv']

# %%
import os

os.listdir("../data/raw")
# Out:
# ['charts.csv.zip', 'Most Streamed Spotify Songs 2024.csv.zip', 'listeners.csv']

# %%
listeners_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
listeners_df.isnull().sum()
# Out:
# Artist         0
# Listeners      0
# Daily Trend    0
# Peak           0
# PkListeners    0
# dtype: int64

# %%
listeners_df.dtypes
# Out:
# Artist           str
# Listeners        str
# Daily Trend      str
# Peak           int64
# PkListeners      str
# dtype: object

# %%
listeners_df.shape
# Out:
# (2500, 5)

# %%
listeners_df.head()
# Out:
#          Artist    Listeners Daily Trend  Peak  PkListeners
# 0    The Weeknd  107,592,328    -138,880     1  113,034,886
# 1  Taylor Swift  101,003,302         889     2  101,003,302
# 2    Ed Sheeran   76,475,126     -68,137     2   87,934,910
# 3      Dua Lipa   76,421,916     -71,356     4   77,778,397
# 4     Bad Bunny   76,162,057    -199,052     3   83,950,570

# %%
listeners_df = pd.read_csv("../data/raw/listeners.csv")

# %%
import pandas as pd
